# %% [markdown]
# <a href="https://colab.research.google.com/github/Imparth2803/machine_learning/blob/Clustering/MeanShift_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import MeanShift
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
cordinates = [[2,2,3],[6,7,8],[5,10,13]]
x,_ = make_blobs(n_samples=150,centers=cordinates,cluster_std=0.60)

# %%
data_fig = plt.figure(figsize=(10,8))
ax = data_fig.add_subplot(111,projection='3d')
ax.scatter(x[:,0],x[:,1],x[:,2],marker='o',color='purple')
plt.show()

# %%
from sklearn.cluster import estimate_bandwidth

bandwidth = estimate_bandwidth(x,quantile=0.2, n_samples=500)
print(bandwidth)
# Out:
# 1.493005481727475

# %%
msc =MeanShift(bandwidth = bandwidth, bin_seeding=True)
msc.fit(x)
cluster_centres = msc.cluster_centers_
labels = msc.labels_
cluster_label = np.unique(labels)
n_clusters =len(cluster_label)
n_clusters
# Out:
# 3

# %%
msc_fig = plt.figure(figsize=(10,8))
ax = msc_fig.add_subplot(111,projection='3d')
ax.scatter(x[:,0],x[:,1],x[:,2],marker='o',color='blue')
ax.scatter(cluster_centres[:,0],cluster_centres[:,1],cluster_centres[:,2],marker='o',color='red', s = 400, linewidth = 5 , zorder =10)
plt.title('Estimated number of clusters: %d' % n_clusters )
plt.show()
